# %% [markdown]
# Os comandos abaixo carregam o famoso dataset do titanic no objeto chamado *df*. Explore a tabela e responda as seguintes questões **sempre colocando o código em Python utilizado para chegar às respostas.**
#
# 1) Quantas pessoas sobreviveram ao acidente?
# 2) Quantas criancas menores de 12 anos sobreviveram ao acidente?
# 3) Quantas pessoas embarcaram nos portos de Southampton OU Queenstow?
# 4) Crie um objeto chamado **passageiras** que seleciona somente as passageiras.
# 5) Crie um objeto chamado **criancas_cherbourg** que seleciona as crianças com menos de 12 anos E que embarcaram na cidade de Cherbourg.
# 6) Crie um objeto chamado **titanic_menor** e selecione as colunas de *nome*, *idade*, *classe* e *embarque*
# 7) Supondo que o valor da tarifa no dataset está em libras, e que 1£ = R$ 6.43, crie uma nova coluna chamada **tarifa_real** que contenha a tarifa de embarque em reais.
# 8) Agrupe pela coluna sobreviveu e calcule o número de passageiros por grupo (sim/nao)
# 9) Agrupe pelo local de embarque e calcule a média e a mediana da tarifa de cada grupo.
# 10) Agrupe pela classe e conte a quantidade de pessoas por classe
# 11) Agrupe pela classe e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveu de acordo com cada classe. Quem sobreviveu mais? A classe mais alta ou a mais baixa?
# 12) Agrupe pelo sexo e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveram de acordo com o sexo. Quem sobreviveu mais? Homens ou mulheres?

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/titanic.csv')
df
# Out:
#      id_passageiro sobreviveu  classe  \
# 0                1        nao       3
# 1                2        sim       1
# 2                3        sim       3
# 3                4        sim       1
# 4                5        nao       3
# ..             ...        ...     ...
# 886            887        nao       2
# 887            888        sim       1
# 888            889        nao       3
# 889            890        sim       1
# 890            891        nao       3
#
#                                                   nome       sexo  idade  \
# 0                              Braund, Mr. Owen Harris  masculino   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                               Heikkinen, Miss. Laina   feminino   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                             Allen, Mr. William Henry  masculino   35.0
# ...

# %%
df['sobreviveu'].value_counts()
# Out:
# nao    549
# sim    342
# Name: sobreviveu, dtype: int64

# %%
#exercício 1
sobreviventes = (df['sobreviveu'] == 'sim').sum()
print('Sobreviveram {} pessoas'.format(sobreviventes))
# Out:
# Sobreviveram 342 pessoas

# %%
#exercício 2
sobreviventes = (df['sobreviveu'] == 'sim').sum() and (df['idade'] < 12).sum()
print('Sobreviveram {} pessoas com menos de 12 anos'.format(sobreviventes))
# Out:
# Sobreviveram 68 pessoas com menos de 12 anos

# %%
#exercício 3
embarque = (df['embarque'] == 'Southampton').sum() or (df['embarque'] == 'Queenstow').sum()
print('Embarcaram nos portos de Southampton ou Queenstow {} pessoas'.format(embarque))
# Out:
# Embarcaram nos portos de Southampton ou Queenstow 644 pessoas

# %%
#exercício 4
passageiras = df.copy()
passageiras.loc[passageiras['sexo'].isin(['feminino'])]
# Out:
#      id_passageiro sobreviveu  classe  \
# 1                2        sim       1
# 2                3        sim       3
# 3                4        sim       1
# 8                9        sim       3
# 9               10        sim       2
# ..             ...        ...     ...
# 880            881        sim       2
# 882            883        nao       3
# 885            886        nao       3
# 887            888        sim       1
# 888            889        nao       3
#
#                                                   nome      sexo  idade  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  feminino   38.0
# 2                               Heikkinen, Miss. Laina  feminino   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  feminino   35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  feminino   27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  feminino   14.0
# ...

# %%
# exercício 5
criancas_cherbourg = df.copy()
criancas_cherbourg.loc[(criancas_cherbourg['embarque'] == 'Cherbourg') & (criancas_cherbourg['idade'] < 12)]
# Out:
#      id_passageiro sobreviveu  classe  \
# 43              44        sim       2
# 381            382        sim       3
# 448            449        sim       3
# 469            470        sim       3
# 644            645        sim       3
# 691            692        sim       3
# 731            732        nao       3
# 803            804        sim       3
# 827            828        sim       2
# 852            853        nao       3
#
#                                          nome       sexo  idade  \
# 43   Laroche, Miss. Simonne Marie Anne Andree   feminino   3.00
# 381               Nakid, Miss. Maria ("Mary")   feminino   1.00
# 448            Baclini, Miss. Marie Catherine   feminino   5.00
# 469             Baclini, Miss. Helene Barbara   feminino   0.75
# 644                    Baclini, Miss. Eugenie   feminino   0.75
# 691                        Karun, Miss. Manca   feminino   4.00
# 731                  Hassan, Mr. Houssein G N  masculino  11.00
# ...

# %%
# exercício 6 - Crie um objeto chamado **titanic_menor** e selecione as colunas de *nome*, *idade*, *classe* e *embarque*
titanic_menor = df.copy()
titanic_menor[['nome','idade','classe','embarque']]
# Out:
#                                                   nome  idade  classe  \
# 0                              Braund, Mr. Owen Harris   22.0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0       1
# 2                               Heikkinen, Miss. Laina   26.0       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0       1
# 4                             Allen, Mr. William Henry   35.0       3
# ..                                                 ...    ...     ...
# 886                              Montvila, Rev. Juozas   27.0       2
# 887                       Graham, Miss. Margaret Edith   19.0       1
# 888           Johnston, Miss. Catherine Helen "Carrie"    NaN       3
# 889                              Behr, Mr. Karl Howell   26.0       1
# 890                                Dooley, Mr. Patrick   32.0       3
#
#         embarque
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# ...

# %%
# exercício 7 - Supondo que o valor da tarifa no dataset está em libras, e que 1£ = R$ 6.43, 
# crie uma nova coluna chamada **tarifa_real** que contenha a tarifa de embarque em reais.
df2 = df.copy()
df2['tarifa_real'] = df2['tarifa']*6.43
df2
# Out:
#      id_passageiro sobreviveu  classe  \
# 0                1        nao       3
# 1                2        sim       1
# 2                3        sim       3
# 3                4        sim       1
# 4                5        nao       3
# ..             ...        ...     ...
# 886            887        nao       2
# 887            888        sim       1
# 888            889        nao       3
# 889            890        sim       1
# 890            891        nao       3
#
#                                                   nome       sexo  idade  \
# 0                              Braund, Mr. Owen Harris  masculino   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                               Heikkinen, Miss. Laina   feminino   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                             Allen, Mr. William Henry  masculino   35.0
# ...

# %%
#exercício 8 - Agrupe pela coluna sobreviveu e calcule o número de passageiros por grupo (sim/nao)
df.groupby(['sobreviveu']).count()
# Out:
#             id_passageiro  classe  nome  sexo  idade  irmaos_conjuge  \
# sobreviveu
# nao                   549     549   549   549    424             549
# sim                   342     342   342   342    290             342
#
#             pais_criancas  passagem  tarifa  cabine  embarque
# sobreviveu
# nao                   549       549     549      68       549
# sim                   342       342     342     136       340

# %%
# exercício 9 -  Agrupe pelo local de embarque e calcule a média e a mediana da tarifa de cada grupo.

df[['embarque', 'tarifa']].groupby('embarque').agg(['mean', 'median'])
# Out:
#                    tarifa
#                      mean   median
# embarque
# Cherbourg    12709.345662  37.0042
# Queenstow     2002.842913   7.7500
# Southampton   2015.306986  18.7500

# %%
#exercício 10 - Agrupe pela classe e conte a quantidade de pessoas por classe
df.groupby(['classe']).agg('count')
# Out:
#         id_passageiro  sobreviveu  nome  sexo  idade  irmaos_conjuge  \
# classe
# 1                 216         216   216   216    186             216
# 2                 184         184   184   184    173             184
# 3                 491         491   491   491    355             491
#
#         pais_criancas  passagem  tarifa  cabine  embarque
# classe
# 1                 216       216     216     176       214
# 2                 184       184     184      16       184
# 3                 491       491     491      12       491

# %%
# exercício 11 - Agrupe pela classe e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveu de acordo com cada classe. 
# Quem sobreviveu mais? A classe mais alta ou a mais baixa?
df.groupby(['sobreviveu', 'classe']).agg('count')
# Out:
#                    id_passageiro  nome  sexo  idade  irmaos_conjuge  \
# sobreviveu classe
# nao        1                  80    80    80     64              80
#            2                  97    97    97     90              97
#            3                 372   372   372    270             372
# sim        1                 136   136   136    122             136
#            2                  87    87    87     83              87
#            3                 119   119   119     85             119
#
#                    pais_criancas  passagem  tarifa  cabine  embarque
# sobreviveu classe
# nao        1                  80        80      80      59        80
#            2                  97        97      97       3        97
#            3                 372       372     372       6       372
# sim        1                 136       136     136     117       134
#            2                  87        87      87      13        87
# ...

# %%
# Com base na tabela acima e na coluna id_passageiro, a classe que mais sobreviveu foi a classe 1

# %%
# exercício 12 - Agrupe pelo sexo e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveram de acordo com o sexo. 
# Quem sobreviveu mais? Homens ou mulheres?
df.groupby(['sobreviveu', 'sexo']).agg('count')
# Out:
#                       id_passageiro  classe  nome  idade  irmaos_conjuge  \
# sobreviveu sexo
# nao        feminino              81      81    81     64              81
#            masculino            468     468   468    360             468
# sim        feminino             233     233   233    197             233
#            masculino            109     109   109     93             109
#
#                       pais_criancas  passagem  tarifa  cabine  embarque
# sobreviveu sexo
# nao        feminino              81        81      81       6        81
#            masculino            468       468     468      62       468
# sim        feminino             233       233     233      91       231
#            masculino            109       109     109      45       109

# %%
# Com base na tabela acima e na coluna id_passageiro, mais Mulheres sobreviveram
